# %% [markdown]
# <a href="https://colab.research.google.com/github/mn-ethel/python-basics-for-ML.1/blob/main/If_else_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# simple if else statement

# %%
a=12
b=90
if (a>b):
  print("a is the greatest")
else:
  print("b is the greatest")
# Out:
# b is the greatest

# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
if (a>b):
  print("first number is the greatest")
else:
  print("second number is the greatest")
# Out:
# enter the first number:100
# enter the second number:45
# a is the greatest

# %% [markdown]
# if elif else statement

# %%
a=17
b=29
c=67
if(b<a>c):
  print("a is the greatest number")
elif(a<b>c):
  print("b is the greatest number")
else:
  print("c is the greatest number") #you do not need to mention the condition for else

# %% [markdown]
# Nested if -if statement inside an if statement

# %%
a=20
b=45
c=63
if (a>b):
  if(a>c):
    print("a is the greatest number.")
  else:
    print("C is the greatest number.")
else:
  if (b>c):
    print("b is the greatest number.")
  else:
    print("c is the greatest number.")
# Out:
# c is the greatest number.
