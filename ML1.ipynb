# %% [markdown]
# <a href="https://colab.research.google.com/github/mn-ethel/python-basics-for-ML.1/blob/main/ML1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Print function

# %%
print("Machine learning" +" is very interesting.")
# Out:
# Machine learning is very interesting.

# %%
print(8)
# Out:
# 8

# %%
print(5+6)

# %% [markdown]
# #Basic data types
#
#
# 1.   int
# 2.   float
# 3.   str

# %%
type(6)
# Out:
# int

# %%
type(9.7)
# Out:
# float

# %%
type(" Learning")
# Out:
# str

# %% [markdown]
# #Contants and Variables

# %%
fruit_type="Orange"
print(fruit_type)
# Out:
# Orange

# %%
fruit_type=("mango")
print(fruit_type)
# Out:
# mango

# %%
fruit1,fruit2,fruit3,=("apple","mango","banana")
print(fruit1)
print(fruit2)
print(fruit3)
# Out:
# apple
# mango
# banana

# %%
a=b=c=5
print(a)
print(b)
print(c)
# Out:
# 5
# 5
# 5

# %% [markdown]
# #Input

# %%
first_number=int(input("Enter the first number:"))
second_number=int(input("Enter the second number:"))
sum=first_number+second_number
print(sum)
# Out:
# Enter the first number:10
# Enter the second number:12
# 22

# %% [markdown]
# #Changing data types

# %%
num=3
print(float(num))
# Out:
# 3.0
