# %% [markdown]
# <a href="https://colab.research.google.com/github/mn-ethel/python-basics-for-ML.1/blob/main/Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# For loop

# %%
book1=int(input("Enter the price of the book:"))
book2=int(input("Enter the price of the book:"))
book3=int(input("Enter the price of the book:"))
book4=int(input("Enter the price of the book:"))
book5=int(input("Enter the price of the book:"))
# Out:
# Enter the price of the laptop:2000

# %%
for i in range(5):
  book_price=int(input("Enter the price of the book"))
# Out:
# Enter the price of the book5000
# Enter the price of the book3000
# Enter the price of the book20000
# Enter the price of the book45000
# Enter the price of the book60000

# %%
numbers=[50,100,150,200]
for i in numbers:
  print(i)
# Out:
# 50
# 100
# 150
# 200

# %% [markdown]
# While loop

# %%
i=5
while i<10:
  print(i)
  i+=1
# Out:
# 5
# 6
# 7
# 8
# 9
